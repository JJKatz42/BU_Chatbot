# %%
import weaviate
import json

# Connect to Weaviate client
client = weaviate.Client(
    url="https://bu-cluster-2-o5pekqq0.weaviate.network",  
    auth_client_secret=weaviate.AuthApiKey(api_key="vXNsRxv6vSJ57r0JKOJxhlBwMDIBadbyvjGC"),  
    additional_headers={
        "X-OpenAI-Api-Key": "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"
    }
)

# %%
# Get all the classes in the schema
classes = client.schema.get()

print(json.dumps(classes, indent=2))
# Out:
# {
#   "classes": [
#     {
#       "class": "Webpage",
#       "description": "This property was generated by Weaviate's auto-schema feature on Mon Jul 17 22:09:57 2023",
#       "invertedIndexConfig": {
#         "bm25": {
#           "b": 0.75,
#           "k1": 1.2
#         },
#         "cleanupIntervalSeconds": 60,
#         "stopwords": {
#           "additions": null,
#           "preset": "en",
#           "removals": null
#         }
#       },
#       "multiTenancyConfig": {
#         "enabled": false
#       },
#       "properties": [
#         {
#           "dataType": [
#             "text"
#           ],
#           "description": "This property was generated by Weaviate's auto-schema feature on Mon Jul 17 22:09:57 2023",
#           "indexFilterable": true,
#           "indexSearchable": true,
#           "name": "timestamp",
#           "tokenization": "word"
#         },
#         {
#           "dataType": [
#             "text"
#           ],
# ...

# %%
# Get the first 3 'Webpage' objects
query = """
{
    Get {
        Webpage(limit: 100) {
            timestamp
            url
            html_content
            text_content
        }
    }
}
"""

result = client.query.raw(query)

# %%
# Print the result
data = result['data']['Get']['Webpage']


for page in data:
    for key, value in page.items():
        # if isinstance(value, str) and len(value) > 1000:
        #     value = value[:1000]  # Truncate value to 1000 characters
        print(f"{key}: {value}")
    print("\n")  # Add a newline between pages

# %%
import pandas as pd

# Assuming 'data' is your list of dictionaries
data = [page for page in result['data']['Get']['Webpage']]

df = pd.DataFrame(data)

# If you want to limit the number of characters to display in each cell, you can use the following:
df = df.applymap(lambda x: str(x)[:2000])

print(df.head(100))  # print the first 100 rows
# Out:
#                                         html_content
# 0  <!DOCTYPE html>\n<!--[if lt IE 7]>     <html c...  \
# 1  \n<!--[if IE ]><![endif]-->\n<!DOCTYPE html>\n...
# 2  <!DOCTYPE html>\n<!--[if lt IE 7]>     <html c...
#
#                                         text_content
# 0  admission decisions are made after a full eval...  \
# 1  //www.bu.edu/sargent/academics/departments-pro...
# 2  student-life/housing/)& [Dining](http://www.bu...
#
#                     timestamp
# 0  2023-07-17T22:06:45.671165  \
# 1  2023-07-17T22:06:44.669694
# 2  2023-07-17T22:06:43.668375
#
#                                                  url
# 0  https://www.bu.edu/met/admissions/apply/now/gr...
# 1  https://www.bu.edu/sargent/admissions/graduate...
# 2  https://www.bu.edu/admissions/why/bu/student/l...
