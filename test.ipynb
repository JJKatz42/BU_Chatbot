# %% [markdown]
# # Embedding the Questrom course webpages

# %%
from google.cloud import aiplatform

aiplatform.init(project="bu-chatbot-388316")

from vertexai.preview.language_models import TextEmbeddingModel
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import os
import html2text


import numpy as np  # Ensure numpy is imported

# Initialize Google AI Platform
aiplatform.init(project="bu-chatbot-388316", location="us-central1")

# Directory containing HTML files
directory = "/workspaces/BU_Chatbot/Questrom_Course_Info"

# Get list of all HTML files
html_files = [f for f in os.listdir(directory) if f.endswith('.html')]

# Dictionary to store each file's content
html_contents = {}

for html_file in html_files:
    with open(f'{directory}/{html_file}', 'r') as f:
        html_content = f.read()
        h1 = html2text.HTML2Text()
        h2 = h1.handle(html_content)
        html_contents[html_file] = h2

# Load model once
model = TextEmbeddingModel.from_pretrained("textembedding-gecko")

# Counter to track number of API requests
api_request_counter = 0


def text_embedding(text_string):
    """Text embedding with a Large Language Model."""
    print(f"API Request Count: {api_request_counter}")
    embeddings = model.get_embeddings([text_string])
    for embedding in embeddings:
        vector = np.array(embedding.values)  # Ensure embedding is a numpy array
        return vector

# Get embeddings for each html file
text1 = list(html_contents.keys())

text2 = []

for content in html_contents.values():
    # if api_request_counter < 17:  # Model's API rate limit (17 is a placeholder, adjust to your actual limit)
    #     text2.append(text_embedding(content))
    #     api_request_counter += 1
    # else:
    #     # Create a zero array of the appropriate embedding size if limit is exceeded
    #     text2.append(np.zeros(768))  # Ensure embedding size matches your model's

    text2.append(text_embedding(content))
    api_request_counter += 1
    
# Creating the DataFrame
df = pd.DataFrame(text1, columns=["text1"])
df["embeddings"] = text2

df.head(50)
# Out:
# API Request Count: 0
# API Request Count: 1
# API Request Count: 2
# API Request Count: 3
# API Request Count: 4
# API Request Count: 5
# API Request Count: 6
# API Request Count: 7
# API Request Count: 8
# API Request Count: 9
# API Request Count: 10
# API Request Count: 11
# API Request Count: 12
# API Request Count: 13
# API Request Count: 14
# API Request Count: 15
# API Request Count: 16
# API Request Count: 17
# API Request Count: 18
# API Request Count: 19
# API Request Count: 20
# API Request Count: 21
# API Request Count: 22
# API Request Count: 23
# API Request Count: 24
# API Request Count: 25
# API Request Count: 26
# API Request Count: 27
# API Request Count: 28
# API Request Count: 29
# API Request Count: 30
# API Request Count: 31
# API Request Count: 32
# API Request Count: 33
# API Request Count: 34
# API Request Count: 35
# API Request Count: 36
# API Request Count: 37
# API Request Count: 38
# API Request Count: 39
# API Request Count: 40
# API Request Count: 41
# API Request Count: 42
# API Request Count: 43
# API Request Count: 44
# API Request Count: 45
# API Request Count: 46
# API Request Count: 47
# API Request Count: 48
# API Request Count: 49
# API Request Count: 50
# API Request Count: 51
# API Request Count: 52
# API Request Count: 53
# API Request Count: 54
# API Request Count: 55
# API Request Count: 56
# API Request Count: 57
# API Request Count: 58
# API Request Count: 59
# API Request Count: 60
# API Request Count: 61
# API Request Count: 62
# API Request Count: 63
# API Request Count: 64
# API Request Count: 65
# API Request Count: 66
# API Request Count: 67
# API Request Count: 68
# API Request Count: 69
# API Request Count: 70
# API Request Count: 71
# API Request Count: 72
# API Request Count: 73
# API Request Count: 74
# API Request Count: 75
# API Request Count: 389
# API Request Count: 390
# API Request Count: 391
# API Request Count: 392
# API Request Count: 393
# API Request Count: 394
# API Request Count: 395
# API Request Count: 396
# API Request Count: 397
# API Request Count: 398
# API Request Count: 399
# API Request Count: 400
# API Request Count: 401
# API Request Count: 402
# API Request Count: 403
# API Request Count: 404
# API Request Count: 405
# API Request Count: 406
# API Request Count: 407
# API Request Count: 408
# API Request Count: 409
# API Request Count: 410
# API Request Count: 411
# API Request Count: 412
# API Request Count: 413
# API Request Count: 414
# API Request Count: 415
# API Request Count: 416
# API Request Count: 417
# API Request Count: 418
# API Request Count: 419
# API Request Count: 420
# API Request Count: 421
# API Request Count: 422
# API Request Count: 423
# API Request Count: 424
# API Request Count: 425
# API Request Count: 426
# API Request Count: 427
# API Request Count: 428
# API Request Count: 429
# API Request Count: 430
# API Request Count: 431
# API Request Count: 432
#                                                 text1
# 0   bu.edu-academics-questrom-courses-qst-mk-867-....  \
# 1   bu.edu-academics-questrom-courses-qst-is-498-....
# 2   bu.edu-academics-questrom-courses-qst-mo-430-....
# 3   bu.edu-academics-questrom-courses-qst-es-735-....
# 4   bu.edu-academics-questrom-courses-qst-si-498-....
# 5   bu.edu-academics-questrom-courses-qst-ac-998-....
# 6   bu.edu-academics-questrom-courses-qst-qm-899-....
# 7   bu.edu-academics-questrom-courses-qst-mf-990-....
# 8   bu.edu-academics-questrom-courses-qst-is-479-....
# 9   bu.edu-academics-questrom-courses-qst-fe-460-....
# 10  bu.edu-academics-questrom-courses-qst-si-998-....
# 11  bu.edu-academics-questrom-courses-qst-is-889-....
# 12  bu.edu-academics-questrom-courses-qst-om-990-....
# 13  bu.edu-academics-questrom-courses-qst-im-445-....
# 14  bu.edu-academics-questrom-courses-qst-fe-498-....
# 15  bu.edu-academics-questrom-courses-qst-qm-221-....
# 16  bu.edu-academics-questrom-courses-qst-ba-476-....
# 17  bu.edu-academics-questrom-courses-qst-ac-710-....
# 18  bu.edu-academics-questrom-courses-qst-sr-898-....
# 19  bu.edu-academics-questrom-courses-qst-fe-459-....
# 20  bu.edu-academics-questrom-courses-qst-mk-835-....
# 21  bu.edu-academics-questrom-courses-qst-is-223-....
# 22  bu.edu-academics-questrom-courses-qst-si-898-....
# 23  bu.edu-academics-questrom-courses-qst-ba-222-....
# 24  bu.edu-academics-questrom-courses-qst-ac-831-....
# 25  bu.edu-academics-questrom-courses-qst-is-841-....
# 26  bu.edu-academics-questrom-courses-qst-la-343-....
# 27  bu.edu-academics-questrom-courses-qst-fe-454-....
# 28  bu.edu-academics-questrom-courses-qst-ac-860-....
# 29  bu.edu-academics-questrom-courses-qst-si-814-....
# 30  bu.edu-academics-questrom-courses-qst-fe-722-....
# 31  bu.edu-academics-questrom-courses-qst-mk-723-....
# 32  bu.edu-academics-questrom-courses-qst-mk-852-....
# 33  bu.edu-academics-questrom-courses-qst-pl-855-....
# 34  bu.edu-academics-questrom-courses-qst-mo-990-....
# 35  bu.edu-academics-questrom-courses-qst-is-998-....
# 36  bu.edu-academics-questrom-courses-qst-ac-469-....
# 37  bu.edu-academics-questrom-courses-qst-is-754-....
# 38  bu.edu-academics-questrom-courses-qst-mo-442-....
# 39  bu.edu-academics-questrom-courses-qst-ms-744-....
# 40  bu.edu-academics-questrom-courses-qst-hm-710-....
# 41  bu.edu-academics-questrom-courses-qst-hm-898-....
# 42  bu.edu-academics-questrom-courses-qst-hm-717-....
# 43  bu.edu-academics-questrom-courses-qst-mo-860-....
# 44  bu.edu-academics-questrom-courses-qst-mf-702-....
# 45  bu.edu-academics-questrom-courses-qst-ac-865-....
# 46  bu.edu-academics-questrom-courses-qst-mf-790-....
# 47  bu.edu-academics-questrom-courses-qst-is-469-....
# 48  bu.edu-academics-questrom-courses-qst-mf-600-....
# 49  bu.edu-academics-questrom-courses-qst-is-428-....
#
#                                            embeddings
# 0   [-0.004325422924011946, -0.04752451553940773, ...
# 1   [-0.004595464561134577, -0.042916011065244675,...
# 2   [-0.00987178459763527, -0.050861671566963196, ...
# 3   [-0.015086178667843342, -0.06140953674912453, ...
# 4   [-0.009621339850127697, -0.04652352258563042, ...
# 5   [-0.007730515208095312, -0.055893201380968094,...
# 6   [-0.0034074829891324043, -0.05145184323191643,...
# 7   [-0.001197927980683744, -0.048734068870544434,...
# 8   [-0.0015936787240207195, -0.04541222006082535,...
# 9   [-0.007622821722179651, -0.05097649618983269, ...
# 10  [-0.00882689654827118, -0.05158215016126633, 0...
# 11  [-0.01124629471451044, -0.057073045521974564, ...
# 12  [-0.01104456651955843, -0.047398053109645844, ...
# 13  [-0.012788048945367336, -0.05737195536494255, ...
# 14  [0.004140129778534174, -0.04037998989224434, 0...
# 15  [0.003925209399312735, -0.05341964587569237, 0...
# 16  [-0.009076393209397793, -0.0582534484565258, 0...
# 17  [-0.006068723276257515, -0.046627480536699295,...
# 18  [-0.0029801323544234037, -0.04637117683887482,...
# 19  [-0.0002495726221241057, -0.0602312795817852, ...
# 20  [0.0015561498003080487, -0.04744806885719299, ...
# 21  [0.0007235436351038516, -0.050641320645809174,...
# 22  [-0.007141385227441788, -0.051897790282964706,...
# 23  [-0.003804416162893176, -0.05732711777091026, ...
# 24  [-0.014276327565312386, -0.04545725882053375, ...
# 25  [-0.005451141390949488, -0.05527999997138977, ...
# 26  [0.005698020104318857, -0.04288347437977791, 0...
# 27  [-0.0013729328056797385, -0.04515284672379494,...
# 28  [-0.006859422195702791, -0.04889644682407379, ...
# 29  [-0.012087428011000156, -0.051887914538383484,...
# 30  [0.004102848470211029, -0.04425278306007385, 0...
# 31  [-0.0073410929180681705, -0.04478313773870468,...
# 32  [-0.011460389941930771, -0.053324781358242035,...
# 33  [-0.013534631580114365, -0.0349092073738575, -...
# 34  [-0.012415211647748947, -0.05258367955684662, ...
# 35  [-0.0044992826879024506, -0.046256206929683685...
# 36  [-0.010280909016728401, -0.04911293089389801, ...
# 37  [-0.005863312631845474, -0.036181092262268066,...
# 38  [-0.020862314850091934, -0.06259070336818695, ...
# 39  [-0.010645348578691483, -0.05146375298500061, ...
# 40  [-0.004612610675394535, -0.05679113417863846, ...
# 41  [-0.0012900126166641712, -0.046246498823165894...
# 42  [-0.00024421326816082, -0.049109116196632385, ...
# 43  [-0.012493712827563286, -0.062162596732378006,...
# 44  [0.010385628789663315, -0.04483436420559883, 0...
# 45  [-0.011324268765747547, -0.05560050904750824, ...
# 46  [-0.00246867211535573, -0.05383759364485741, 0...
# 47  [-0.0023210174404084682, -0.05226287990808487,...
# 48  [0.011290185153484344, -0.05087977647781372, 0...
# 49  [-0.003145703813061118, -0.039939962327480316,...

# %% [markdown]
# # Calculate the similarity score for the target string

# %%
# Embedding for the target string
target_string = "sm 132"
target_embedding = text_embedding(target_string)

# Calculate similarity score
similarity_scores = cosine_similarity(np.vstack(df['embeddings'].values), [target_embedding])  # Ensure cosine_similarity receives numpy arrays
df['similarity_score'] = similarity_scores

# Sorting the dataframe by similarity scores in descending order and getting the top 3
df = df.sort_values(by='similarity_score', ascending=False)

df.head(50)
# Out:
# API Request Count: 433
#                                                  text1
# 349  bu.edu-academics-questrom-courses-qst-sm-275-....  \
# 94   bu.edu-academics-questrom-courses-qst-sm-132-....
# 316  bu.edu-academics-questrom-courses-qst-fe-712-....
# 429  bu.edu-academics-questrom-courses-qst-mk-469-....
# 143  bu.edu-academics-questrom-courses-qst-mf-728-....
# 55   bu.edu-academics-questrom-courses-qst-mo-856-....
# 33   bu.edu-academics-questrom-courses-qst-pl-855-....
# 412  bu.edu-academics-questrom-courses-qst-es-740-....
# 263  bu.edu-academics-questrom-courses-qst-mk-442-....
# 241  bu.edu-academics-questrom-courses-qst-pl-851-....
# 231  bu.edu-academics-questrom-courses-qst-ba-860-....
# 140  bu.edu-academics-questrom-courses-qst-mk-470-....
# 321  bu.edu-academics-questrom-courses-qst-mf-772-....
# 166  bu.edu-academics-questrom-courses-qst-ms-749-....
# 158  bu.edu-academics-questrom-courses-qst-es-720-....
# 164  bu.edu-academics-questrom-courses-qst-is-919-....
# 144  bu.edu-academics-questrom-courses-qst-fe-430-....
# 345  bu.edu-academics-questrom-courses-qst-fe-822-....
# 210  bu.edu-academics-questrom-courses-qst-pl-325-....
# 122  bu.edu-academics-questrom-courses-qst-mf-793-....
# 100  bu.edu-academics-questrom-courses-qst-ms-759-....
# 402  bu.edu-academics-questrom-courses-qst-la-365-....
# 422  bu.edu-academics-questrom-courses-qst-mo-221-....
# 409  bu.edu-academics-questrom-courses-qst-ba-780-....
# 350  bu.edu-academics-questrom-courses-qst-mf-840-....
# 101  bu.edu-academics-questrom-courses-qst-hm-801-....
# 131  bu.edu-academics-questrom-courses-qst-ms-772-....
# 60   bu.edu-academics-questrom-courses-qst-fe-449-....
# 75   bu.edu-academics-questrom-courses-qst-ba-830-....
# 353  bu.edu-academics-questrom-courses-qst-fe-456-....
# 416  bu.edu-academics-questrom-courses-qst-fe-713-....
# 236  bu.edu-academics-questrom-courses-qst-si-464-....
# 395  bu.edu-academics-questrom-courses-qst-qm-222-....
# 147  bu.edu-academics-questrom-courses-qst-hm-817-....
# 138  bu.edu-academics-questrom-courses-qst-hm-703-....
# 325  bu.edu-academics-questrom-courses-qst-si-435-....
# 264  bu.edu-academics-questrom-courses-qst-qm-323-....
# 66   bu.edu-academics-questrom-courses-qst-es-872-....
# 431  bu.edu-academics-questrom-courses-qst-pl-730-....
# 253  bu.edu-academics-questrom-courses-qst-fe-342-....
# 215  bu.edu-academics-questrom-courses-qst-fe-820-....
# 177  bu.edu-academics-questrom-courses-qst-ms-747-....
# 413  bu.edu-academics-questrom-courses-qst-om-441-....
# 30   bu.edu-academics-questrom-courses-qst-fe-722-....
# 21   bu.edu-academics-questrom-courses-qst-is-223-....
# 136  bu.edu-academics-questrom-courses-qst-mk-845-....
# 98   bu.edu-academics-questrom-courses-qst-om-726-....
# 109  bu.edu-academics-questrom-courses-qst-si-422-....
# 278  bu.edu-academics-questrom-courses-qst-ms-771-....
# 124  bu.edu-academics-questrom-courses-qst-si-482-....
#
#                                             embeddings  similarity_score
# 349  [-0.01035457942634821, -0.05419669672846794, 0...          0.609720
# 94   [0.000735165667720139, -0.034375086426734924, ...          0.608682
# 316  [-0.002177775837481022, -0.053912509232759476,...          0.607697
# 429  [-0.005400892347097397, -0.051528409123420715,...          0.602867
# 143  [0.0017214161343872547, -0.05224233493208885, ...          0.602591
# 55   [-0.0010086417896673083, -0.05264900624752045,...          0.602403
# 33   [-0.013534631580114365, -0.0349092073738575, -...          0.600646
# 412  [-0.019551245495676994, -0.06512408703565598, ...          0.600101
# 263  [-0.005877649411559105, -0.05679074674844742, ...          0.599893
# 241  [-0.01635211892426014, -0.04593505710363388, -...          0.598709
# 231  [-0.003970155492424965, -0.05136939883232117, ...          0.597497
# 140  [-0.013977785594761372, -0.0570659413933754, 0...          0.596982
# 321  [0.0025734850205481052, -0.051469773054122925,...          0.596933
# 166  [-0.009974376298487186, -0.05652168020606041, ...          0.596539
# 158  [-0.018061434850096703, -0.06512980163097382, ...          0.596458
# 164  [-0.015725452452898026, -0.04553670808672905, ...          0.596333
# 144  [-0.013490337878465652, -0.03925604000687599, ...          0.596178
# 345  [0.001824190723709762, -0.04899676516652107, 0...          0.596162
# 210  [-0.00869803223758936, -0.03548697754740715, 0...          0.596135
# 122  [0.001691478886641562, -0.05185260623693466, 0...          0.595528
# 100  [-0.011657689698040485, -0.056894101202487946,...          0.595256
# 402  [0.0071198116056621075, -0.04746551439166069, ...          0.595178
# 422  [-0.009918155148625374, -0.05108803138136864, ...          0.594914
# 409  [-0.005870547611266375, -0.04926076531410217, ...          0.594592
# 350  [0.006239968352019787, -0.05694670230150223, 0...          0.594264
# 101  [-0.0007255526725202799, -0.04209517687559128,...          0.593772
# 131  [-0.006360298953950405, -0.046962443739175797,...          0.593743
# 60   [0.00635732663795352, -0.051444195210933685, 0...          0.593666
# 75   [-0.0046180784702301025, -0.051215432584285736...          0.593563
# 353  [-0.005443243775516748, -0.0493227057158947, 0...          0.593412
# 416  [-0.0014370095450431108, -0.05431685596704483,...          0.593378
# 236  [-0.00540166487917304, -0.04930458217859268, 0...          0.593028
# 395  [-0.007302918005734682, -0.051633503288030624,...          0.592935
# 147  [-0.004213892854750156, -0.051104869693517685,...          0.592871
# 138  [0.0033218394964933395, -0.03724851459264755, ...          0.592830
# 325  [-0.01991278864443302, -0.042165160179138184, ...          0.592780
# 264  [-0.009959949180483818, -0.045133076608181, 0....          0.592326
# 66   [-0.01158811990171671, -0.06782392412424088, 0...          0.592326
# 431  [-0.0019847871735692024, -0.04829355701804161,...          0.592227
# 253  [0.0027350964955985546, -0.04399757459759712, ...          0.592168
# 215  [0.0021864348091185093, -0.05548279732465744, ...          0.592110
# 177  [-0.004898263607174158, -0.04666464775800705, ...          0.591797
# 413  [-0.008068311028182507, -0.04707377776503563, ...          0.591690
# 30   [0.004102848470211029, -0.04425278306007385, 0...          0.591567
# 21   [0.0007235436351038516, -0.050641320645809174,...          0.591443
# 136  [-0.006737005431205034, -0.038714244961738586,...          0.591269
# 98   [-0.0026969288010150194, -0.05192370340228081,...          0.591189
# 109  [-0.011030031368136406, -0.054903753101825714,...          0.590985
# 278  [-0.010660458356142044, -0.05197298899292946, ...          0.590840
# 124  [-0.011376743204891682, -0.0590788796544075, 0...          0.590739

# %% [markdown]
# ## Helper function

# %%
import re

def remove_non_letters(text):
    """Removes non-letter characters from a string."""
    return re.sub(r'[^a-zA-Z]', ' ', text)

# %% [markdown]
# # Retrieve the top three most similar files and clean the HTML text

# %%
from vertexai.preview.language_models import (ChatModel, InputOutputTextPair)

chat_model = ChatModel.from_pretrained("chat-bison@001")

import html2text


# top1 = [top_3_courses[2]]
df_top_3 = df.head(3)
df_top_3.head(3)

top_3_courses = df_top_3['text1'].tolist()


print(f"Top 3 courses similar to {target_string}: {top_3_courses}")


text = ""
for html_file in top_3_courses:
    with open(f'{directory}/{html_file}', 'r') as f:
        html_content = f.read()
        h1 = html2text.HTML2Text()
        h1.ignore_links = True
        h2 = h1.handle(html_content)
        h3 = h2[:2000]
        text = text + h3 + "\n"
        # print(h2)


# text = text.replace("  ", " ")
# text = text[:4000]

# with open('Questrom_Course_Info/bu.edu-academics-questrom-courses-qst-sm-132-.html', 'r') as f:
#     html_content = f.read()
#     h1 = html2text.HTML2Text()
#     h1.ignore_links = True
#     h2 = h1.handle(html_content)
#     text = h2

# print(text)
# Out:
# Top 3 courses similar to sm 132: ['bu.edu-academics-questrom-courses-qst-sm-275-.html', 'bu.edu-academics-questrom-courses-qst-sm-132-.html', 'bu.edu-academics-questrom-courses-qst-fe-712-.html']

# %% [markdown]
# # Input the prompt and context into the chat model: chat-bison

# %%
chat = chat_model.start_chat(
    context=f"Here is the text from BU course webpages {text}",
    examples=[
        InputOutputTextPair(
            input_text="Give me a description of the course.",
            output_text="Introduces the basic principles, methods, and challenges of modern managerial accounting. Covers traditional topics such as job-order costing, cost-volume-profit analysis, budgeting and variance analysis, profitability analysis, relevant costs for decision making, and cost-plus pricing, as well as emerging topics such as Activity-Based Cost (ABC) accounting. ",
        ),
        InputOutputTextPair(
            input_text="What are the prerequesits for the course?",
            output_text="QST SM131; CAS MA120, MA121, or MA123 previous or concurrent; sophomore standing.",
        ),
    ],
    temperature=0.1,
    max_output_tokens=100,
    top_p=0.001,
    top_k=0.01,
)

prompt = "describe the course Measuring Financial Value"

print(chat.send_message(f"{prompt}"))
# Out:
# I'm not able to help with that, as I'm only a language model. If you believe this is an error, please send us your feedback.
